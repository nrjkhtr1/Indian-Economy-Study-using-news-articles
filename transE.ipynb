# %% [markdown]
# # TransE algorithm

# %% [markdown]
# TranseE algorithm to convert openIE triplets to embeddings.

# %%
import pandas as pd
import numpy as np
columns = ["confidence_score", "subject", "relation", "object"]
text_file = pd.read_csv("text_articles\output.txt", sep="\t", encoding='latin1', header = None)

# %%
text_file
# Out:
#        0                  1                     2  \
# 0    1.0  state governments  verify customers due
# 1    1.0  state governments                verify
# 2    1.0  state governments  verify customers due
# 3    1.0  state governments  verify customers due
# 4    1.0  state governments  verify customers due
# ..   ...                ...                   ...
# 857  1.0          companies    would however have
# 858  1.0          companies    would however have
# 859  1.0          companies    would however have
# 860  1.0          companies    would however have
# 861  1.0          companies            would have
#
#                                                      3
# 0                 poor response from state governments
# 1                            linked non-core customers
# 2         poor response from certain state governments
# 3                      response from state governments
# 4                                        poor response
# ..                                                 ...
# 857  obligation into agreement with existing market...
# 858  obligation by entering into suitable agreement...
# 859                                         obligation
# 860                           flexibility to discharge
# 861  obligation by entering into suitable agreement...
#
# [862 rows x 4 columns]

# %%
text_file.columns = columns

# %% [markdown]
# Dataframe contains the <b>triplets (subject, relation, object) </b> and <b>confident score</b>. Here confident score  represent how much confidence algorithm have to convert sentence into the triplets.

# %%
text_file
# Out:
#      confidence_score            subject              relation  \
# 0                 1.0  state governments  verify customers due
# 1                 1.0  state governments                verify
# 2                 1.0  state governments  verify customers due
# 3                 1.0  state governments  verify customers due
# 4                 1.0  state governments  verify customers due
# ..                ...                ...                   ...
# 857               1.0          companies    would however have
# 858               1.0          companies    would however have
# 859               1.0          companies    would however have
# 860               1.0          companies    would however have
# 861               1.0          companies            would have
#
#                                                 object
# 0                 poor response from state governments
# 1                            linked non-core customers
# 2         poor response from certain state governments
# 3                      response from state governments
# 4                                        poor response
# ..                                                 ...
# 857  obligation into agreement with existing market...
# 858  obligation by entering into suitable agreement...
# 859                                         obligation
# 860                           flexibility to discharge
# 861  obligation by entering into suitable agreement...
#
# [862 rows x 4 columns]

# %%
# to count the occurence of the subject
from collections import Counter
Counter(np.array(text_file['subject'])).most_common()
# Out:
# [('government', 56),
#  ('companies', 40),
#  ('lacklustre revenue collections', 39),
#  ('cii', 39),
#  ("nepal 's prince dipendra", 25),
#  ('customs duties', 19),
#  ('average customs duties', 19),
#  ('india', 16),
#  ('it', 14),
#  ('interest rates', 14),
#  ('vajpayee', 14),
#  ('state governments', 13),
#  ('delegates', 13),
#  ('board', 10),
#  ('us', 9),
#  ('lazard capital', 9),
#  ('capital', 9),
#  ('control', 9),
#  ('indian companies', 8),
#  ('rana talwar', 8),
#  ('bids', 8),
#  ('deficit', 7),
#  ('2002', 7),
#  ('yashwant sinha harping', 6),
#  ('demand stimulus needed', 6),
#  ('demand stimulus', 6),
#  ('fiscal deficit', 6),
#  ('capacities', 6),
#  ('benicio del toro', 6),
#  ('sachin tendulkar', 6),
#  ('sir', 6),
#  ('hamid karzai', 6),
#  ('karzai', 6),
#  ('oil sector regulator', 6),
#  ('enron', 5),
#  ('clinton', 5),
#  ('bsf men', 5),
#  ('3', 5),
#  ('steven s reinemund', 5),
#  ('hewlett packard', 5),
#  ('afghanistan', 5),
#  ('its two subsidiaries', 5),
#  ('its subsidiaries', 5),
#  ('proposed oil sector regulator', 5),
#  ('private', 5),
#  ('inter-company agreements', 5),
#  ('agreements', 5),
#  ('ministry', 4),
#  ('confederation', 4),
#  ('gdp growth', 4),
#  ('corporate sector', 4),
#  ('sector', 4),
#  ('debt overhang', 4),
#  ('corporate debt overhang', 4),
#  ('julia roberts', 4),
#  ('russell crowe', 4),
#  ('qrs', 4),
#  ('14', 4),
#  ('jayalalitha', 4),
#  ('23', 4),
#  ('prime minister ab vajpayee', 4),
#  ('minister ab vajpayee', 4),
#  ('pervez musharraf', 4),
#  ('musharraf', 4),
#  ('corporate india', 4),
#  ('j jayalalitha', 4),
#  ('indian agent', 4),
#  ('agent', 4),
#  ('argentina president fernando de la rua', 4),
#  ('president fernando de la rua', 4),
#  ('hutchison', 3),
#  ('global meltdown', 3),
#  ('other benchmark indices', 3),
#  ('benchmark indices', 3),
#  ('sebi', 3),
#  ('us 64', 3),
#  ('talks', 3),
#  ("pakistan 's president pervez musharraf", 3),
#  ("sorcerer 's stone", 3),
#  ('ambanis', 3),
#  ('police officials', 3),
#  ('seven police officials', 3),
#  ('andhra pradesh', 2),
#  ('fiscal year 2001 02', 2),
#  ('initial estimates', 2),
#  ('estimates', 2),
#  ('gradual turnaround', 2),
#  ('4.5 % growth', 2),
#  ('alone', 2),
#  ('this', 2),
#  ('trade', 2),
#  ('software companies', 2),
#  ('leading espouser', 2),
#  ('espouser', 2),
#  ('merger', 2),
#  ('meltdown', 2),
#  ("tehelka 's defence deal", 2),
#  ('his role', 2),
#  ('gtb', 2),
#  ('tension', 2),
#  ('fardeen khan', 2),
#  ('16', 2),
#  ('29', 2),
#  ('philip morris', 2),
#  ('et', 2),
#  ('agra summit', 2),
#  ('other directors', 2),
#  ('two other directors', 2),
#  ("ge 's legendary executive jack welch", 2),
#  ("ge 's executive jack welch", 2),
#  ("ge 's legendary chief executive jack welch", 2),
#  ("ge 's chief executive jack welch", 2),
#  ('osama bin', 2),
#  ('osama bin laden', 2),
#  ('madhavrao scindia', 2),
#  ('hewlett family', 2),
#  ('airlines plane', 2),
#  ('american airlines plane', 2),
#  ('match referee mike denness', 2),
#  ('punitive measures', 2),
#  ('george harrison', 2),
#  ('20 others', 2),
#  ('five armed terrorists', 2),
#  ('armed terrorists', 2),
#  ('others', 2),
#  ('elite kovalam ashok beach resort', 2),
#  ('hotels', 2),
#  ('last date', 2),
#  ('date', 2),
#  ('supplies', 2),
#  ('move', 1),
#  ('yashwant sinha', 1),
#  ('they', 1),
#  ('2002 03', 1),
#  ('35 %', 1),
#  ('presence', 1),
#  ('growth', 1),
#  ('substantial discounts', 1),
#  ('discounts', 1),
#  ('500 listed manufacturing companies', 1),
#  ('margins', 1),
#  ('days', 1),
#  ('to welcome return', 1),
#  ('rise', 1),
#  ('competitiveness', 1),
#  ('can benchmark', 1),
#  ('two biggest problems', 1),
#  ('biggest problems', 1),
#  ('reducing', 1),
#  ('restructuring', 1),
#  ('there will significant greenfield project', 1),
#  ('activities', 1),
#  ('substantial consolidation', 1),
#  ('links', 1),
#  ('uti', 1),
#  ('trust bank', 1),
#  ('global trust bank', 1),
#  ('largest private bank', 1),
#  ('vijayaraje scindia', 1),
#  ('mother', 1),
#  ('tinseltown', 1),
#  ('couple', 1),
#  ('scores perfect 10', 1),
#  ('finance minister yashwant sinha fires round ii reforms', 1),
#  ('rumours', 1),
#  ('sebi bans short sales', 1),
#  ('sebi bans sales', 1),
#  ('sebi probes ketan parekh', 1),
#  ("sebi probes ketan parekh 's role", 1),
#  ('anand rathi', 1),
#  ('tehelka', 1),
#  ('payment crisis', 1),
#  ('banks', 1),
#  ('cooperative banks', 1),
#  ('her role', 1),
#  ('fear', 1),
#  ('automatic fdi', 1),
#  ('dewang mehta', 1),
#  ('world', 1),
#  ('steven', 1),
#  ('his contract', 1),
#  ('president musharraf', 1),
#  ('president pervez musharraf', 1),
#  ('pakistan president musharraf', 1),
#  ('pakistan president pervez musharraf', 1),
#  ("minister 's invitation", 1),
#  ("prime minister 's invitation", 1),
#  ('prime minister', 1),
#  ('nepal', 1),
#  ('11 members', 1),
#  ('jury', 1),
#  ('hfcl kerry packer venture', 1),
#  ('nine broadcasting ï¿½', 1),
#  ('hfcl kerry packer joint venture', 1),
#  ('connection', 1),
#  ('lakme', 1),
#  ('cbi arrests ketan parekh', 1),
#  ('weakness', 1),
#  ('ge', 1),
#  ('wtc towers', 1),
#  ('terrorists attack pentagon', 1),
#  ('mediation', 1),
#  ('pakistan', 1),
#  ('alliance air', 1),
#  ('china', 1),
#  ('members', 1),
#  ('142 members', 1),
#  ('dynegy', 1),
#  ('sorcerer', 1),
#  ('cent stake', 1),
#  ('cricket', 1),
#  ('bcci', 1),
#  ('icc', 1),
#  ('draft', 1),
#  ('argentina', 1),
#  ('noted film actor ashok kumar', 1),
#  ('film actor ashok kumar', 1),
#  ('parliament', 1),
#  ('country', 1),
#  ('196 rooms', 1),
#  ('kerala', 1),
#  ('kovalam ashok beach resort', 1),
#  ('10 hotels', 1),
#  ('minimum', 1),
#  ('other', 1),
#  ('policy', 1),
#  ('power', 1),
#  ('facilities', 1),
#  ('powers', 1),
#  ('supplying petrol', 1),
#  ('government regulator board', 1),
#  ('suitable agreement', 1)]

# %%
# to count the occurence of the object
Counter(np.array(text_file['object'])).most_common()
# Out:
# [('india', 12),
#  ('trade', 5),
#  ('power', 5),
#  ('range', 4),
#  ('range of', 4),
#  ('much more trade', 4),
#  ('china', 4),
#  ('more trade', 4),
#  ('margins', 4),
#  ('serious proportions', 4),
#  ('proportions', 4),
#  ('decision', 4),
#  ('82', 4),
#  ('20 long years', 4),
#  ('20 years', 4),
#  ('while injured', 4),
#  ('injured', 4),
#  ('april 2002', 4),
#  ('us', 3),
#  ('pakistan president pervez musharraf', 3),
#  ('president musharraf', 3),
#  ('president pervez musharraf', 3),
#  ('pakistan president musharraf', 3),
#  ("prime minister 's invitation", 3),
#  ("minister 's invitation", 3),
#  ('new york', 3),
#  ('j', 3),
#  ('head of government', 3),
#  ('head', 3),
#  ('pakistan', 3),
#  ('tranche', 3),
#  ('public interest', 3),
#  ('customers', 2),
#  ('deadline', 2),
#  ('one month', 2),
#  ('2001', 2),
#  ('fresh sector investments', 2),
#  ('need impetus', 2),
#  ('private sector investments', 2),
#  ('much need impetus', 2),
#  ('sector investments', 2),
#  ('fresh private sector investments', 2),
#  ('will region of 5.0 % to 5.1 %', 2),
#  ('will region', 2),
#  ('will region of 5.0 % to 5.1 % of gdp', 2),
#  ('will region to 5.1 %', 2),
#  ('will region of 5.0 %', 2),
#  ('will region to 5.1 % of gdp', 2),
#  ('35 % from 25 %', 2),
#  ('35 % in top slab from 25 % to 20 %', 2),
#  ('35 % to 30 % from 25 %', 2),
#  ('35 % to 30 % in top slab from 25 % to 20 %', 2),
#  ('35 % to 30 % from 25 % to 20 %', 2),
#  ('35 % to 30 % in top slab', 2),
#  ('35 % from 25 % to 20 %', 2),
#  ('35 % to 30 % in slab from 25 % to 20 %', 2),
#  ('35 % to 30 %', 2),
#  ('35 % in slab from 25 %', 2),
#  ('35 % in slab', 2),
#  ('35 % in slab from 25 % to 20 %', 2),
#  ('35 % to 30 % in slab', 2),
#  ('35 % to 30 % in slab from 25 %', 2),
#  ('35 % in top slab from 25 %', 2),
#  ('5 percentage points', 2),
#  ('35 %', 2),
#  ('35 % to 30 % in top slab from 25 %', 2),
#  ('35 % in top slab', 2),
#  ('market shares', 2),
#  ('will pressed', 2),
#  ('will hard pressed', 2),
#  ('rise in profitability of petroleum majors', 2),
#  ('rise in profitability', 2),
#  ('deregulation of oil sector', 2),
#  ('deregulation', 2),
#  ('rise', 2),
#  ('major', 2),
#  ('control', 2),
#  ('happens', 2),
#  ('detriment', 2),
#  ('detriment of india', 2),
#  ('detriment of corporate india', 2),
#  ('if happens', 2),
#  ('madhavrao scindia', 2),
#  ('industry', 2),
#  ('downslide', 2),
#  ('uti bank', 2),
#  ('hits indian markets', 2),
#  ('hits markets', 2),
#  ('showing', 2),
#  ('poor showing', 2),
#  ('fire', 2),
#  ('best actor award', 2),
#  ('actor award', 2),
#  ('his role', 2),
#  ('0over', 2),
#  ('chairman of pepsico inc. india born indra nooyi', 2),
#  ('chairman', 2),
#  ('chairman of pepsico inc. indra nooyi', 2),
#  ('chairman of pepsico inc. born indra nooyi', 2),
#  ('chief minister', 2),
#  ('minister of tamil nadu', 2),
#  ('minister', 2),
#  ('chief minister of tamil nadu', 2),
#  ('his contract with worldtel', 2),
#  ('his contract', 2),
#  ('11 members of family including his parents', 2),
#  ('11 members in kathmandu', 2),
#  ('11 members of royal family in kathmandu including his parents', 2),
#  ('11 members in kathmandu including his parents', 2),
#  ('11 members of royal family', 2),
#  ('11 members of royal family including his parents', 2),
#  ('11 members', 2),
#  ('11 members including his parents', 2),
#  ('11 members of family in kathmandu including his parents', 2),
#  ('11 members of family in kathmandu', 2),
#  ('11 members of royal family in kathmandu', 2),
#  ('11 members of family', 2),
#  ('television business ï¿½', 2),
#  ('delhi', 2),
#  ('agra summit', 2),
#  ('exit up to 3,000 units at fixed prices', 2),
#  ('exit up to 3,000 units', 2),
#  ('exit up to 3,000 units at prices', 2),
#  ('bail', 2),
#  ('uti', 2),
#  ('fun', 2),
#  ('serious fun', 2),
#  ('times awards night', 2),
#  ('economic times awards night', 2),
#  ('30bn debt', 2),
#  ('literature', 2),
#  ('to merge with icici bank', 2),
#  ('to merge', 2),
#  ('icici bank', 2),
#  ('merge', 2),
#  ('merge with icici bank', 2),
#  ("'99", 2),
#  ('cbi for kickbacks', 2),
#  ('cbi', 2),
#  ('cbi for accepting kickbacks', 2),
#  ("china 's entry", 2),
#  ('york', 2),
#  ('bankruptcy', 2),
#  ('age 90', 2),
#  ('ensuing attack', 2),
#  ('attack', 2),
#  ('killed', 2),
#  ('sponsored terrorism', 2),
#  ('pakistan sponsored terrorism', 2),
#  ('terrorism', 2),
#  ('as country rises', 2),
#  ('country rises in anger', 2),
#  ('as country rises in anger', 2),
#  ('country rises', 2),
#  ('head of aghanistan government', 2),
#  ('head of interim government', 2),
#  ('office', 2),
#  ('head of aghanistan interim government', 2),
#  ('hotels', 2),
#  ('disinvestment', 2),
#  ('first tranche', 2),
#  ('disinvestment of six hotels including ashok bangalore', 2),
#  ('disinvestment of six hotels', 2),
#  ('has retained for sale', 2),
#  ('has retained as advisors for sale of properties', 2),
#  ('has fixed', 2),
#  ('has retained as global advisors for sale of properties', 2),
#  ('has retained as global advisors for sale', 2),
#  ('has fixed at february 15', 2),
#  ('has retained as advisors', 2),
#  ('has retained as advisors for sale', 2),
#  ('has retained for sale of properties', 2),
#  ('has retained', 2),
#  ('has retained as global advisors', 2),
#  ('supply of controlled products', 2),
#  ('supply', 2),
#  ('supply of products', 2),
#  ('may entered into for exchange of petroleum products', 2),
#  ('may entered into for exchange', 2),
#  ('may entered', 2),
#  ('may entered into for exchange for period', 2),
#  ('may entered into for exchange of petroleum products for period', 2),
#  ('april 1 2002', 2),
#  ('even after decontrolled', 2),
#  ('after decontrolled', 2),
#  ('decontrolled', 2),
#  ('even decontrolled', 2),
#  ('even after decontrolled from april 1 2002', 2),
#  ('after decontrolled from april 1 2002', 2),
#  ('interest', 2),
#  ('obligation by entering into agreement', 2),
#  ('obligation into suitable agreement with existing marketeers', 2),
#  ('obligation by entering', 2),
#  ('obligation by entering into suitable agreement with marketeers', 2),
#  ('obligation into suitable agreement with marketeers', 2),
#  ('obligation into agreement with existing marketeers', 2),
#  ('obligation into agreement', 2),
#  ('flexibility', 2),
#  ('flexibility to discharge', 2),
#  ('obligation into suitable agreement', 2),
#  ('obligation', 2),
#  ('obligation into agreement with marketeers', 2),
#  ('obligation by entering into agreement with existing marketeers', 2),
#  ('obligation by entering into suitable agreement', 2),
#  ('obligation by entering into agreement with marketeers', 2),
#  ('obligation by entering into suitable agreement with existing marketeers',
#   2),
#  ('poor response from state governments', 1),
#  ('linked non-core customers', 1),
#  ('poor response from certain state governments', 1),
#  ('response from state governments', 1),
#  ('poor response', 1),
#  ('response', 1),
#  ('linked customers', 1),
#  ('non-core customers', 1),
#  ('response from certain state governments', 1),
#  ('ensure', 1),
#  ('to ensure', 1),
#  ('verification of such customers', 1),
#  ('headway', 1),
#  ('much headway', 1),
#  ('cliche', 1),
#  ('worst cliche of 2001', 1),
#  ('7 per cent growth', 1),
#  ('cliche of 2001', 1),
#  ('worst cliche', 1),
#  ('intensive brainstorming session', 1),
#  ('day long brainstorming session', 1),
#  ('intensive day long brainstorming session', 1),
#  ('brainstorming session', 1),
#  ('...', 1),
#  ('real gdp growth', 1),
#  ('gdp growth', 1),
#  ('demand stimulus needed', 1),
#  ('demand stimulus needed for eliminating surplus capacities', 1),
#  ('demand stimulus', 1),
#  ('demand stimulus needed for surplus capacities', 1),
#  ('will insufficient', 1),
#  ('year', 1),
#  ('manufacturing sector', 1),
#  ('agricultural income', 1),
#  ('2001 02', 1),
#  ('first half of 2002 03', 1),
#  ('deficit increasing to something like rs.', 1),
#  ('result in deficit increasing to something like rs.', 1),
#  ('result in deficit increasing from budget estimate to something', 1),
#  ('deficit to something', 1),
#  ('deficit increasing from budget estimate of rs. 116,314 crore to something like rs.',
#   1),
#  ('to result in deficit increasing from budget estimate of rs. 116,314 crore',
#   1),
#  ('to result in deficit increasing from budget estimate', 1),
#  ('to result in deficit', 1),
#  ('to result in deficit increasing to something like rs.', 1),
#  ('result in deficit increasing from budget estimate', 1),
#  ('result in deficit', 1),
#  ('result in deficit increasing from budget estimate of rs. 116,314 crore', 1),
#  ('deficit increasing from budget estimate of rs. 116,314 crore', 1),
#  ('deficit increasing to something', 1),
#  ('deficit to something like rs.', 1),
#  ('to result in deficit increasing to something', 1),
#  ('to result in deficit increasing from budget estimate to something like rs.',
#   1),
#  ('result in deficit to something', 1),
#  ('deficit', 1),
#  ('deficit increasing', 1),
#  ('to result in deficit increasing', 1),
#  ('deficit increasing from budget estimate to something', 1),
#  ('deficit increasing from budget estimate', 1),
#  ('to result in deficit increasing from budget estimate to something', 1),
#  ('result in deficit increasing from budget estimate to something like rs.',
#   1),
#  ('to result in deficit to something like rs.', 1),
#  ('result in deficit increasing from budget estimate of rs. 116,314 crore to something',
#   1),
#  ('result in deficit increasing from budget estimate of rs. 116,314 crore to something like rs.',
#   1),
#  ('result in deficit increasing', 1),
#  ('to result in deficit increasing from budget estimate of rs. 116,314 crore to something',
#   1),
#  ('to result in deficit to something', 1),
#  ('expected', 1),
#  ('result in deficit to something like rs.', 1),
#  ('deficit increasing from budget estimate of rs. 116,314 crore to something',
#   1),
#  ('result', 1),
#  ('result in deficit increasing to something', 1),
#  ('to result', 1),
#  ('deficit increasing from budget estimate to something like rs.', 1),
#  ('to result in deficit increasing from budget estimate of rs. 116,314 crore to something like rs.',
#   1),
#  ('will year of competition', 1),
#  ('will year of greater competition from within india', 1),
#  ('will year', 1),
#  ('will year of greater competition', 1),
#  ('will year of even greater competition', 1),
#  ('will year of even greater competition from within india', 1),
#  ('will year of competition from within india', 1),
#  ('customs duties', 1),
#  ('average customs duties', 1),
#  ('top slab', 1),
#  ('competition from imports', 1),
#  ('competition', 1),
#  ('presence of chinese goods', 1),
#  ('three fronts', 1),
#  ('2002 03', 1),
#  ('at least 25 %', 1),
#  ('private sector', 1),
#  ('manufacturing', 1),
#  ('over', 1),
#  ('to welcome return to sanity in valuations', 1),
#  ('sanity', 1),
#  ('welcome return to sanity in valuations', 1),
#  ('return', 1),
#  ('return to sanity', 1),
#  ('to return', 1),
#  ('to welcome return', 1),
#  ('return to sanity in valuations', 1),
#  ('to welcome return in valuations', 1),
#  ('return in valuations', 1),
#  ('average throughout 2002', 1),
#  ('to return to sanity', 1),
#  ('welcome return to sanity', 1),
#  ('average', 1),
#  ('to return in valuations', 1),
#  ('to return to sanity in valuations', 1),
#  ('to welcome return to sanity', 1),
#  ('valuations', 1),
#  ('p e ratio', 1),
#  ('welcome return', 1),
#  ('welcome return in valuations', 1),
#  ('level of industries', 1),
#  ('doing', 1),
#  ('level', 1),
#  ('doing well', 1),
#  ('software companies', 1),
#  ('profitability of petroleum majors', 1),
#  ('will watchword', 1),
#  ('best in world', 1),
#  ('quarter of 2002', 1),
#  ('second quarter of 2002', 1),
#  ('quarter', 1),
#  ('second quarter', 1),
#  ('larger borrowing programme', 1),
#  ('borrowing programme', 1),
#  ('larger borrowing programme for 2002 03', 1),
#  ('borrowing programme for 2002 03', 1),
#  ('2002', 1),
#  ('will consolidated through friendly takeovers', 1),
#  ('will consolidated', 1),
#  ('will consolidated through takeovers', 1),
#  ('instead will consolidated through takeovers', 1),
#  ('instead will consolidated through friendly takeovers', 1),
#  ('instead will consolidated', 1),
#  ('m', 1),
#  ('consolidation', 1),
#  ('banking sector', 1),
#  ('significant m', 1),
#  ('consolidation in telecommunications', 1),
#  ('telecommunications', 1),
#  ('lcs', 1),
#  ('guarantees', 1),
#  ('underworld', 1),
#  ('country', 1),
#  ('most glittery twosome', 1),
#  ('spokesperson', 1),
#  ('brand', 1),
#  ('france telecom', 1),
#  ('orange brand', 1),
#  ('counter guarantee', 1),
#  ("government 's counter guarantee", 1),
#  ('bse sensex', 1),
#  ('role in gtb price spurt prior to announcement of merger with uti bank', 1),
#  ('gtb price spurt', 1),
#  ('trading', 1),
#  ('it', 1),
#  ('defence deal', 1),
#  ('tv', 1),
#  ('tapes air', 1),
#  ('bullion market', 1),
#  ('best actress', 1),
#  ('her role', 1),
#  ('gladiator', 1),
#  ('his role in gladiator', 1),
#  ('her role in erin brockovich', 1),
#  ('erin brockovich', 1),
#  ('actress', 1),
#  ('supporting actor award', 1),
#  ('his role in traffic', 1),
#  ('traffic', 1),
#  ('las vegas fame', 1),
#  ('best supporting actor award', 1),
#  ('evidence of nexus between parekh rigging', 1),
#  ('evidence rigging', 1),
#  ('evidence of nexus rigging', 1),
#  ('batch', 1),
#  ('last batch', 1),
#  ('batch of 715 items', 1),
#  ('last batch of 715 items', 1),
#  ('sezs', 1),
#  ('quake hit areas', 1),
#  ('hit areas', 1),
#  ('bhuj', 1),
#  ('areas', 1),
#  ('gujarat', 1),
#  ('merger with uti bank', 1),
#  ('merger', 1),
#  ('sydney', 1),
#  ('as tension builds', 1),
#  ('tension builds', 1),
#  ('meghalaya', 1),
#  ('tension builds between india', 1),
#  ('as tension builds between india', 1),
#  ('wealthiest man by sam walton of wal mart', 1),
#  ('transaction', 1),
#  ('reinemund', 1),
#  ('transaction of narcotics', 1),
#  ('worldtel', 1),
#  ('invitation', 1),
#  ('prince dipendra', 1),
#  ('kathmandu', 1),
#  ('himself', 1),
#  ('$ 3bn in damages', 1),
#  ('$ 3bn', 1),
#  ('philip morris', 1),
#  ('dhirubhai ambani', 1),
#  ('awards', 1),
#  ("'92 stock market scam", 1),
#  ('as talks flounder', 1),
#  ('impasse over issues', 1),
#  ('talks flounder', 1),
#  ('impasse', 1),
#  ('impasse over issues of kashmir', 1),
#  ('their collections', 1),
#  ('madhavpura case', 1),
#  ("enron 's stock price", 1),
#  ('stock price', 1),
#  ('for 25bn in stock become', 1),
#  ('for 25bn in stock to become', 1),
#  ('25bn in stock to become', 1),
#  ('compaq', 1),
#  ('25bn in stock become', 1),
#  ('legendary chief executive', 1),
#  ('washington', 1),
#  ('osama bin laden', 1),
#  ('osama bin laden in return for easing', 1),
#  ('court ruling', 1),
#  ('osama bin laden in return for easing of sanctions', 1),
#  ('osama bin', 1),
#  ('chieminister of tamil nadu', 1),
#  ('cash', 1),
#  ('terms', 1),
#  ('chieminister', 1),
#  ('president', 1),
#  ('osama bin laden in return', 1),
#  ('supreme court ruling', 1),
#  ("'98 sanctions", 1),
#  ('congress', 1),
#  ('age 56', 1),
#  ('flight cd 7444 from mumbai to delhi', 1),
#  ('attacks', 1),
#  ('led attacks', 1),
#  ('attacks on afghanistan', 1),
#  ('us led attacks on afghanistan', 1),
#  ('us led attacks', 1),
#  ('led attacks on afghanistan', 1),
#  ('biowarfare', 1),
#  ('form', 1),
#  ('form of anthrax', 1),
#  ('nobel prize', 1),
#  ('prize for literature', 1),
#  ('nobel prize for literature', 1),
#  ('prize', 1),
#  ('buy', 1),
#  ('compaq buy', 1),
#  ('entry', 1),
#  ('enron', 1),
#  ('brought', 1),
#  ('brought to big screen', 1),
#  ('brought to screen', 1),
#  ('stone', 1),
#  ('kumar birla', 1),
#  ('10 per cent stake in l', 1),
#  ('l', 1),
#  ('10 per cent stake', 1),
#  ('suspended one test ban', 1),
#  ('one test ban', 1),
#  ('suspended one test ban for tampering', 1),
#  ('one test ban for tampering', 1),
#  ('rest of series', 1),
#  ('rest', 1),
#  ('match referee mike denness removed', 1),
#  ('match referee mike denness removed from rest of series', 1),
#  ('match referee mike denness removed from rest', 1),
#  ('six players', 1),
#  ('alternative', 1),
#  ('six indian players', 1),
#  ('un', 1),
#  ('chief officer', 1),
#  ('chief executive officer of stanchart', 1),
#  ('chief officer of stanchart', 1),
#  ('executive officer', 1),
#  ('officer', 1),
#  ('chief executive officer', 1),
#  ('executive officer of stanchart', 1),
#  ('officer of stanchart', 1),
#  ('cancer', 1),
#  ('age 58', 1),
#  ('national currency', 1),
#  ('currency', 1),
#  ('long discussions', 1),
#  ('head of elected government', 1),
#  ('karzai', 1),
#  ('discussions', 1),
#  ('head of afghan government', 1),
#  ('hamid karzai', 1),
#  ('head of new afghan government', 1),
#  ('head of elected afghan government', 1),
#  ('head of new government', 1),
#  ('head of new elected afghan government', 1),
#  ('head of new elected government', 1),
#  ('stand', 1),
#  ('hardline stand against terrorism', 1),
#  ('hardline stand against pakistan sponsored terrorism', 1),
#  ('stand against pakistan sponsored terrorism', 1),
#  ('hardline stand', 1),
#  ('stand against sponsored terrorism', 1),
#  ('hardline stand against sponsored terrorism', 1),
#  ('stand against terrorism', 1),
#  ('winter session', 1),
#  ('high commissioner', 1),
#  ('commissioner', 1),
#  ('commissioner from pakistan', 1),
#  ('high commissioner from pakistan', 1),
#  ('anger', 1),
#  ('third tranche of tourism development corporation hotels', 1),
#  ('tranche of india tourism development corporation hotels', 1),
#  ('bids', 1),
#  ('tranche of tourism development corporation hotels', 1),
#  ('third tranche', 1),
#  ('third tranche of india tourism development corporation hotels', 1),
#  ('initial bids', 1),
#  ('149 rooms', 1),
#  ('196 rooms along hotel airport ashok at kolkata', 1),
#  ('kerala with 196 rooms along hotel airport ashok at kolkata with 149 rooms',
#   1),
#  ('have invited for 10 hotels', 1),
#  ('have already invited for 10 hotels in tranche', 1),
#  ('second tranche', 1),
#  ('have already invited for 10 hotels in second tranche', 1),
#  ('have invited for 10 hotels in tranche', 1),
#  ('have already invited', 1),
#  ('have invited for 10 hotels in second tranche', 1),
#  ('have invited', 1),
#  ('have already invited for 10 hotels', 1),
#  ('thrid', 1),
#  ('hotel jaipur ashok', 1),
#  ('transition period of two years', 1),
#  ('transition period', 1),
#  ('dismantling of administered pricing mechanism', 1),
#  ('dismantling of administered pricing mechanism from april 1 2002', 1),
#  ('dismantling of pricing mechanism from april 1 2002', 1),
#  ('dismantling of pricing mechanism', 1),
#  ('transition period of two years for oil sector', 1),
#  ('transition period for oil sector', 1),
#  ('dismantling', 1),
#  ('shifting', 1),
#  ('retail outlets', 1),
#  ('hospitality arrangements', 1),
#  ('present hospitality arrangements', 1),
#  ('supply mechanism', 1),
#  ('continue', 1),
#  ('to continue', 1),
#  ('supply mechanism by companies', 1),
#  ('place', 1),
#  ('outlets', 1),
#  ('supply mechanism by private companies', 1),
#  ('marketing obligations not having in one part of country', 1),
#  ('implementation of plan', 1),
#  ('implementation', 1),
#  ('likely', 1),
#  ('petroleum sector', 1),
#  ('decontrolled from april 1 2002', 1),
#  ('leash', 1),
#  ('even decontrolled from april 1 2002', 1),
#  ('tight leash', 1),
#  ('their equitable distribution', 1),
#  ('same', 1),
#  ('policy', 1),
#  ('their distribution', 1),
#  ('matter of policy relating to petroleum sector', 1),
#  ('matter of policy relating', 1),
#  ('matter', 1),
#  ('matter of policy relating to downstream petroleum sector', 1),
#  ('matter of policy', 1),
#  ('management', 1),
#  ('activities', 1),
#  ('activities pertaining to sector', 1),
#  ('certain activities pertaining to downstream sector', 1),
#  ('certain activities', 1),
#  ('activities pertaining to downstream sector', 1),
#  ('powers', 1),
#  ('certain activities pertaining', 1),
#  ('activities pertaining', 1),
#  ('certain activities pertaining to sector', 1),
#  ('rural areas', 1),
#  ('existing marketeers', 1)]

# %%
# to count the occurence of the relation
Counter(np.array(text_file['relation'])).most_common()
# Out:
# [('is in', 36),
#  ('fall from', 36),
#  ('has', 34),
#  ('is expected', 26),
#  ('would have', 18),
#  ('considers', 16),
#  ('would however have', 16),
#  ('will', 13),
#  ('will in', 12),
#  ('result in', 12),
#  ('may invites', 12),
#  ('massacres', 12),
#  ('allegedly massacres', 12),
#  ('is', 11),
#  ('is with', 11),
#  ('expects', 10),
#  ('takes office as', 10),
#  ('may', 10),
#  ('select karzai as', 9),
#  ('prohibit', 9),
#  ('giving need impetus to', 8),
#  ('be', 8),
#  ('dies at', 8),
#  ('may takes 0over as', 8),
#  ('may sworn in as', 8),
#  ('retires after', 8),
#  ('decide', 8),
#  ('quits as', 8),
#  ('adopt', 8),
#  ('forced out', 8),
#  ('have', 8),
#  ('keep leash', 8),
#  ('ensure', 7),
#  ('offers', 7),
#  ('verify customers due', 6),
#  ('also doing', 6),
#  ('doing', 6),
#  ('wins', 6),
#  ('visit', 6),
#  ('may accepts', 6),
#  ('backs', 6),
#  ('chargesheeted by', 6),
#  ('were', 6),
#  ('invited bids for', 6),
#  ('verify', 5),
#  ('surrender', 5),
#  ('faces', 5),
#  ('has proposed transition period after', 5),
#  ('fails in', 5),
#  ('has become', 4),
#  ('had', 4),
#  ('create', 4),
#  ('giving', 4),
#  ('are in', 4),
#  ('continue', 4),
#  ('has already attained', 4),
#  ('has attained', 4),
#  ('harden by', 4),
#  ('has target', 4),
#  ('stocks', 4),
#  ('slide on', 4),
#  ('gets', 4),
#  ('scrapped on', 4),
#  ('killed', 4),
#  ('may renews', 4),
#  ('gathers for', 4),
#  ('gathers at', 4),
#  ('buy compaq', 4),
#  ('crashes in', 4),
#  ('were killed in', 4),
#  ('die', 4),
#  ('recalls', 4),
#  ('has proposed', 4),
#  ('also expects', 3),
#  ('will harden to', 3),
#  ('will surely harden to', 3),
#  ('announce', 3),
#  ('finds', 3),
#  ('visits', 3),
#  ('flounder due', 3),
#  ('wants', 3),
#  ('hardline stand against', 3),
#  ('stand against', 3),
#  ('has completed', 3),
#  ('has already completed', 3),
#  ('setting up', 3),
#  ('failed', 2),
#  ('make', 2),
#  ('will see', 2),
#  ('initial estimates of are', 2),
#  ('estimates of are', 2),
#  ('fall by', 2),
#  ('will intensify', 2),
#  ('also doing trade with', 2),
#  ('doing trade with', 2),
#  ('maintain', 2),
#  ('significantly improve', 2),
#  ('improve', 2),
#  ('expects p e ratio to', 2),
#  ('expects software companies at', 2),
#  ('expects rise with', 2),
#  ('also expects rise with', 2),
#  ('facing many companies in', 2),
#  ('will harden', 2),
#  ('will surely harden', 2),
#  ('expects consolidation in', 2),
#  ('invoke', 2),
#  ('mother of', 2),
#  ('as', 2),
#  ('gives up', 2),
#  ('arrest', 2),
#  ('slide by', 2),
#  ('come under', 2),
#  ('is named', 2),
#  ('is named actress for', 2),
#  ('wins actor award for', 2),
#  ('gets actor award for', 2),
#  ('visits areas in', 2),
#  ('pulls out', 2),
#  ('may takes', 2),
#  ('may arrested for', 2),
#  ('pay', 2),
#  ('shuts down', 2),
#  ('arrives in', 2),
#  ('arrives for', 2),
#  ('fails', 2),
#  ('released on', 2),
#  ('subramanyam of', 2),
#  ('buy', 2),
#  ('write off', 2),
#  ('resigns following', 2),
#  ('mediation in', 2),
#  ('resigns as', 2),
#  ('faces biowarfare in', 2),
#  ('merge with', 2),
#  ('chargesheeted in', 2),
#  ('back', 2),
#  ('ratify', 2),
#  ('sell', 2),
#  ('removed from', 2),
#  ('taken against', 2),
#  ('dollar as', 2),
#  ('select karzai after', 2),
#  ('select', 2),
#  ('takes', 2),
#  ('invited', 2),
#  ('are amongst', 2),
#  ('has completed disinvestment in', 2),
#  ('has already completed disinvestment in', 2),
#  ('ensure between', 2),
#  ('ensure supply between', 2),
#  ('setting up supply mechanism of', 2),
#  ('proposes', 2),
#  ('shall monitor', 2),
#  ('keep', 2),
#  ('secure', 2),
#  ('besides has retained power in', 2),
#  ('has retained power in', 2),
#  ('had previuosly extended', 1),
#  ('had previuosly extended deadline by', 1),
#  ('had extended deadline by', 1),
#  ('had extended', 1),
#  ('cliche of', 1),
#  ('worst cliche of', 1),
#  ('harping on', 1),
#  ('came out with', 1),
#  ('is expected at_time', 1),
#  ('will happen in', 1),
#  ('increase in', 1),
#  ('increase by', 1),
#  ('are', 1),
#  ('be welcome', 1),
#  ('goes out', 1),
#  ('gives up brand to', 1),
#  ('invokes', 1),
#  ('scores with', 1),
#  ('hit', 1),
#  ('suspended from', 1),
#  ('expose tapes air on', 1),
#  ('expose', 1),
#  ('dies in', 1),
#  ('killed in', 1),
#  ('builds between', 1),
#  ('s', 1),
#  ('shoots', 1),
#  ('asks', 1),
#  ('announces awards for', 1),
#  ('announces', 1),
#  ('showcase', 1),
#  ('in', 1),
#  ('carry', 1),
#  ('carry terms to', 1),
#  ('waives', 1),
#  ('leader of', 1),
#  ('of', 1),
#  ('nobel prize for', 1),
#  ('prize for', 1),
#  ('t to', 1),
#  ('suggests as', 1),
#  ('review', 1),
#  ('proposed by', 1),
#  ('dies of', 1),
#  ('declares', 1),
#  ('nears', 1),
#  ('commissioner from', 1),
#  ('high commissioner from', 1),
#  ('rises in', 1),
#  ('include hotel jaipur ashok in', 1),
#  ('include', 1),
#  ('would monitor', 1),
#  ('putting in', 1),
#  ('is decontrolled from', 1),
#  ('keep leash on', 1),
#  ('even is decontrolled from', 1),
#  ('issue', 1),
#  ('besides has retained', 1),
#  ('formulate', 1),
#  ('has retained', 1),
#  ('would also have', 1),
#  ('retain', 1),
#  ('take over', 1)]

# %%
# Here i am assigning the id to each entity which is later  used in the algorithm

entity2id = {}
relation2id = {}


# sub_e = "E"
# sub_r = "R"

subjects = text_file.subject.unique()
objects = text_file.object.unique()
entities = np.append(subjects, objects, 0)

unique_relation = np.unique(text_file.relation)
unique_entity = np.unique(entities)

for i in range(len(unique_relation)):
    relation2id[unique_relation[i]] = i

for i in range(len(unique_entity)):
    entity2id[unique_entity[i]] = i

# %%
unique_entity.shape
# Out:
# (781,)

# %%
id2relation = {value:key for key, value in relation2id.items()}

# %%
id2entity = {value:key for key, value in entity2id.items()}

# %%
import tensorflow as tf
import numpy as np
import json
import os
import time
import pickle
import random

# %%
# entity2id
# relation2id
# id2relation
# id2entity

# %%
text_file
# Out:
#      confidence_score            subject              relation  \
# 0                 1.0  state governments  verify customers due
# 1                 1.0  state governments                verify
# 2                 1.0  state governments  verify customers due
# 3                 1.0  state governments  verify customers due
# 4                 1.0  state governments  verify customers due
# ..                ...                ...                   ...
# 857               1.0          companies    would however have
# 858               1.0          companies    would however have
# 859               1.0          companies    would however have
# 860               1.0          companies    would however have
# 861               1.0          companies            would have
#
#                                                 object
# 0                 poor response from state governments
# 1                            linked non-core customers
# 2         poor response from certain state governments
# 3                      response from state governments
# 4                                        poor response
# ..                                                 ...
# 857  obligation into agreement with existing market...
# 858  obligation by entering into suitable agreement...
# 859                                         obligation
# 860                           flexibility to discharge
# 861  obligation by entering into suitable agreement...
#
# [862 rows x 4 columns]

# %%
final = []
for i in range(text_file.shape[0]):
    final.append((entity2id[text_file.iloc[i,1]], relation2id[text_file.iloc[i,2]], entity2id[text_file.iloc[i,3]]))

# %%
final
# Out:
# [(641, 196, 542),
#  (641, 195, 433),
#  (641, 196, 541),
#  (641, 196, 579),
#  (641, 196, 540),
#  (641, 196, 577),
#  (641, 195, 432),
#  (641, 195, 197),
#  (641, 195, 491),
#  (641, 196, 578),
#  (641, 62, 253),
#  (474, 83, 202),
#  (474, 84, 511),
#  (641, 62, 690),
#  (474, 82, 511),
#  (641, 47, 741),
#  (474, 81, 202),
#  (478, 195, 197),
#  (87, 131, 351),
#  (87, 131, 479),
#  (778, 31, 31),
#  (778, 93, 167),
#  (778, 215, 31),
#  (778, 93, 775),
#  (777, 87, 62),
#  (778, 93, 168),
#  (778, 93, 774),
#  (178, 80, 391),
#  (178, 80, 200),
#  (178, 80, 392),
#  (178, 80, 129),
#  (679, 26, 5),
#  (282, 210, 574),
#  (282, 210, 295),
#  (397, 37, 223),
#  (397, 37, 224),
#  (223, 78, 293),
#  (223, 77, 484),
#  (222, 78, 293),
#  (223, 78, 559),
#  (222, 77, 481),
#  (222, 78, 621),
#  (397, 37, 222),
#  (223, 77, 481),
#  (222, 77, 484),
#  (222, 78, 559),
#  (223, 78, 292),
#  (397, 37, 225),
#  (397, 204, 755),
#  (222, 78, 292),
#  (223, 78, 621),
#  (34, 118, 779),
#  (386, 11, 572),
#  (257, 11, 572),
#  (257, 11, 573),
#  (295, 110, 572),
#  (295, 110, 573),
#  (295, 50, 573),
#  (386, 11, 573),
#  (295, 50, 572),
#  (308, 119, 443),
#  (59, 119, 79),
#  (59, 119, 32),
#  (308, 119, 279),
#  (208, 208, 759),
#  (281, 208, 757),
#  (281, 208, 760),
#  (208, 208, 761),
#  (281, 208, 758),
#  (281, 208, 761),
#  (208, 208, 762),
#  (208, 208, 757),
#  (281, 208, 759),
#  (208, 208, 758),
#  (208, 208, 760),
#  (281, 208, 762),
#  (413, 162, 217),
#  (413, 117, 593),
#  (413, 117, 590),
#  (413, 162, 218),
#  (413, 162, 213),
#  (413, 117, 697),
#  (413, 117, 696),
#  (413, 117, 694),
#  (413, 117, 703),
#  (413, 117, 586),
#  (413, 117, 584),
#  (413, 117, 587),
#  (413, 162, 211),
#  (413, 162, 216),
#  (413, 162, 219),
#  (413, 117, 702),
#  (413, 117, 701),
#  (413, 117, 594),
#  (413, 162, 208),
#  (413, 162, 209),
#  (413, 117, 695),
#  (413, 162, 214),
#  (413, 162, 210),
#  (413, 117, 700),
#  (413, 117, 591),
#  (413, 117, 705),
#  (413, 117, 588),
#  (413, 117, 589),
#  (413, 117, 585),
#  (413, 117, 698),
#  (413, 117, 704),
#  (413, 115, 272),
#  (413, 117, 595),
#  (413, 162, 212),
#  (413, 117, 583),
#  (413, 117, 592),
#  (413, 117, 693),
#  (413, 162, 215),
#  (413, 117, 699),
#  (33, 204, 765),
#  (33, 204, 770),
#  (33, 204, 764),
#  (33, 204, 769),
#  (33, 204, 767),
#  (33, 204, 768),
#  (33, 204, 766),
#  (198, 66, 42),
#  (106, 66, 49),
#  (198, 66, 51),
#  (198, 66, 58),
#  (106, 66, 52),
#  (198, 66, 56),
#  (198, 66, 43),
#  (106, 66, 55),
#  (166, 52, 198),
#  (198, 66, 50),
#  (106, 66, 56),
#  (106, 66, 45),
#  (106, 66, 44),
#  (106, 66, 46),
#  (198, 66, 53),
#  (198, 66, 45),
#  (106, 66, 43),
#  (166, 52, 106),
#  (106, 66, 54),
#  (106, 66, 51),
#  (106, 66, 58),
#  (198, 66, 48),
#  (198, 66, 46),
#  (198, 65, 60),
#  (106, 65, 60),
#  (106, 66, 41),
#  (198, 66, 54),
#  (198, 66, 57),
#  (106, 66, 47),
#  (106, 66, 48),
#  (41, 119, 714),
#  (106, 66, 50),
#  (198, 66, 41),
#  (106, 66, 57),
#  (198, 66, 55),
#  (106, 66, 42),
#  (106, 66, 53),
#  (198, 66, 52),
#  (198, 66, 47),
#  (198, 66, 49),
#  (198, 66, 44),
#  (82, 209, 176),
#  (82, 209, 175),
#  (546, 119, 381),
#  (309, 119, 547),
#  (683, 205, 684),
#  (172, 2, 480),
#  (172, 3, 164),
#  (383, 3, 164),
#  (383, 2, 480),
#  (172, 45, 164),
#  (172, 44, 715),
#  (383, 44, 715),
#  (383, 2, 475),
#  (383, 45, 164),
#  (383, 44, 475),
#  (383, 44, 480),
#  (383, 2, 715),
#  (172, 2, 475),
#  (172, 2, 715),
#  (172, 44, 475),
#  (273, 119, 565),
#  (184, 150, 67),
#  (184, 150, 150),
#  (184, 150, 148),
#  (184, 150, 66),
#  (397, 163, 545),
#  (545, 191, 184),
#  (184, 150, 149),
#  (184, 150, 65),
#  (184, 150, 151),
#  (656, 119, 606),
#  (307, 217, 544),
#  (172, 218, 495),
#  (172, 217, 505),
#  (172, 217, 495),
#  (172, 217, 494),
#  (172, 217, 500),
#  (172, 218, 506),
#  (172, 218, 500),
#  (172, 217, 502),
#  (172, 217, 501),
#  (172, 218, 505),
#  (172, 218, 284),
#  (172, 217, 285),
#  (172, 218, 504),
#  (172, 217, 493),
#  (172, 218, 503),
#  (172, 217, 496),
#  (648, 122, 268),
#  (172, 217, 503),
#  (172, 218, 498),
#  (172, 217, 497),
#  (172, 218, 501),
#  (172, 217, 504),
#  (172, 218, 497),
#  (172, 217, 506),
#  (172, 218, 494),
#  (172, 218, 496),
#  (172, 217, 284),
#  (172, 217, 498),
#  (172, 218, 502),
#  (172, 218, 499),
#  (172, 218, 493),
#  (172, 218, 285),
#  (172, 217, 499)]

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
import torch
from torch import nn, optim
import matplotlib.pyplot as plt

# %%
rel_len = len(relation2id)
entity_len = len(entity2id)

# %%
all_entity = unique_entity

# %%
all_entity
# Out:
# array(['$ 3bn', '$ 3bn in damages', "'92 stock market scam",
#        "'98 sanctions", "'99", '...', '0over', '10 hotels',
#        '10 per cent stake', '10 per cent stake in l', '11 members',
#        '11 members in kathmandu',
#        '11 members in kathmandu including his parents',
#        '11 members including his parents', '11 members of family',
#        '11 members of family in kathmandu',
#        '11 members of family in kathmandu including his parents',
#        '11 members of family including his parents',
#        '11 members of royal family',
#        '11 members of royal family in kathmandu',
#        '11 members of royal family in kathmandu including his parents',
#        '11 members of royal family including his parents', '14',
#        '142 members', '149 rooms', '16', '196 rooms',
#        '196 rooms along hotel airport ashok at kolkata', '20 long years',
#        '20 others', '20 years', '2001', '2001 02', '2002', '2002 03',
#        '23', '25bn in stock become', '25bn in stock to become', '29', '3',
#        '30bn debt', '35 %', '35 % from 25 %', '35 % from 25 % to 20 %',
#        '35 % in slab', '35 % in slab from 25 %',
#        '35 % in slab from 25 % to 20 %', '35 % in top slab',
#        '35 % in top slab from 25 %', '35 % in top slab from 25 % to 20 %',
#        '35 % to 30 %', '35 % to 30 % from 25 %',
#        '35 % to 30 % from 25 % to 20 %', '35 % to 30 % in slab',
#        '35 % to 30 % in slab from 25 %',
#        '35 % to 30 % in slab from 25 % to 20 %',
#        '35 % to 30 % in top slab', '35 % to 30 % in top slab from 25 %',
#        '35 % to 30 % in top slab from 25 % to 20 %', '4.5 % growth',
#        '5 percentage points', '500 listed manufacturing companies',
#        '7 per cent growth', '82', 'activities', 'activities pertaining',
#        'activities pertaining to downstream sector',
#        'activities pertaining to sector', 'actor award', 'actress',
#        'afghanistan', 'after decontrolled',
#        'after decontrolled from april 1 2002', 'age 56', 'age 58',
#        'age 90', 'agent', 'agra summit', 'agreements',
#        'agricultural income', 'airlines plane', 'alliance air', 'alone',
#        'alternative', 'ambanis', 'american airlines plane', 'anand rathi',
#        'andhra pradesh', 'anger', 'april 1 2002', 'april 2002', 'areas',
#        'argentina', 'argentina president fernando de la rua',
#        'armed terrorists', 'as country rises',
#        'as country rises in anger', 'as talks flounder',
#        'as tension builds', 'as tension builds between india',
#        'at least 25 %', 'attack', 'attacks', 'attacks on afghanistan',
#        'automatic fdi', 'average', 'average customs duties',
#        'average throughout 2002', 'awards', 'bail', 'banking sector',
#        'bankruptcy', 'banks', 'batch', 'batch of 715 items', 'bcci',
#        'benchmark indices', 'benicio del toro', 'best actor award',
#        'best actress', 'best in world', 'best supporting actor award',
#        'bhuj', 'bids', 'biggest problems', 'biowarfare', 'board',
#        'borrowing programme', 'borrowing programme for 2002 03',
#        'brainstorming session', 'brand', 'brought',
#        'brought to big screen', 'brought to screen', 'bse sensex',
#        'bsf men', 'bullion market', 'buy', 'can benchmark', 'cancer',
#        'capacities', 'capital', 'cash', 'cbi', 'cbi arrests ketan parekh',
#        'cbi for accepting kickbacks', 'cbi for kickbacks', 'cent stake',
#        'certain activities', 'certain activities pertaining',
#        'certain activities pertaining to downstream sector',
#        'certain activities pertaining to sector', 'chairman',
#        'chairman of pepsico inc. born indra nooyi',
#        'chairman of pepsico inc. india born indra nooyi',
#        'chairman of pepsico inc. indra nooyi', 'chief executive officer',
#        'chief executive officer of stanchart', 'chief minister',
#        'chief minister of tamil nadu', 'chief officer',
#        'chief officer of stanchart', 'chieminister',
#        'chieminister of tamil nadu', 'china', "china 's entry", 'cii',
#        'cliche', 'cliche of 2001', 'clinton', 'commissioner',
#        'commissioner from pakistan', 'companies', 'compaq', 'compaq buy',
#        'competition', 'competition from imports', 'competitiveness',
#        'confederation', 'congress', 'connection', 'consolidation',
#        'consolidation in telecommunications', 'continue', 'control',
#        'cooperative banks', 'corporate debt overhang', 'corporate india',
#        'corporate sector', 'counter guarantee', 'country',
#        'country rises', 'country rises in anger', 'couple',
#        'court ruling', 'cricket', 'currency', 'customers',
#        'customs duties', 'date', 'day long brainstorming session', 'days',
#        'deadline', 'debt overhang', 'decision', 'decontrolled',
#        'decontrolled from april 1 2002', 'defence deal', 'deficit',
#        'deficit increasing', 'deficit increasing from budget estimate',
#        'deficit increasing from budget estimate of rs. 116,314 crore',
#        'deficit increasing from budget estimate of rs. 116,314 crore to something',
#        'deficit increasing from budget estimate of rs. 116,314 crore to something like rs.',
#        'deficit increasing from budget estimate to something',
#        'deficit increasing from budget estimate to something like rs.',
#        'deficit increasing to something',
#        'deficit increasing to something like rs.', 'deficit to something',
#        'deficit to something like rs.', 'delegates', 'delhi',
#        'demand stimulus', 'demand stimulus needed',
#        'demand stimulus needed for eliminating surplus capacities',
#        'demand stimulus needed for surplus capacities', 'deregulation',
#        'deregulation of oil sector', 'detriment',
#        'detriment of corporate india', 'detriment of india',
#        'dewang mehta', 'dhirubhai ambani', 'discounts', 'discussions',
#        'disinvestment', 'disinvestment of six hotels',
#        'disinvestment of six hotels including ashok bangalore',
#        'dismantling', 'dismantling of administered pricing mechanism',
#        'dismantling of administered pricing mechanism from april 1 2002',
#        'dismantling of pricing mechanism',
#        'dismantling of pricing mechanism from april 1 2002', 'doing',
#        'doing well', 'downslide', 'draft', 'dynegy',
#        'economic times awards night', 'elite kovalam ashok beach resort',
#        'enron', "enron 's stock price", 'ensuing attack', 'ensure',
#        'entry', 'erin brockovich', 'espouser', 'estimates', 'et',
#        'even after decontrolled',
#        'even after decontrolled from april 1 2002', 'even decontrolled',
#        'even decontrolled from april 1 2002',
#        'evidence of nexus between parekh rigging',
#        'evidence of nexus rigging', 'evidence rigging',
#        'executive officer', 'executive officer of stanchart',
#        'existing marketeers', 'exit up to 3,000 units',
#        'exit up to 3,000 units at fixed prices',
#        'exit up to 3,000 units at prices', 'expected', 'facilities',
#        'fardeen khan', 'fear', 'film actor ashok kumar',
#        'finance minister yashwant sinha fires round ii reforms', 'fire',
#        'first half of 2002 03', 'first tranche', 'fiscal deficit',
#        'fiscal year 2001 02', 'five armed terrorists', 'flexibility',
#        'flexibility to discharge', 'flight cd 7444 from mumbai to delhi',
#        'for 25bn in stock become', 'for 25bn in stock to become', 'form',
#        'form of anthrax', 'france telecom',
#        'fresh private sector investments', 'fresh sector investments',
#        'fun', 'gdp growth', 'ge', "ge 's chief executive jack welch",
#        "ge 's executive jack welch",
#        "ge 's legendary chief executive jack welch",
#        "ge 's legendary executive jack welch", 'george harrison',
#        'gladiator', 'global meltdown', 'global trust bank', 'government',
#        "government 's counter guarantee", 'government regulator board',
#        'gradual turnaround', 'growth', 'gtb', 'gtb price spurt',
#        'guarantees', 'gujarat', 'hamid karzai', 'happens',
#        'hardline stand',
#        'hardline stand against pakistan sponsored terrorism',
#        'hardline stand against sponsored terrorism',
#        'hardline stand against terrorism', 'has fixed',
#        'has fixed at february 15', 'has retained',
#        'has retained as advisors', 'has retained as advisors for sale',
#        'has retained as advisors for sale of properties',
#        'has retained as global advisors',
#        'has retained as global advisors for sale',
#        'has retained as global advisors for sale of properties',
#        'has retained for sale', 'has retained for sale of properties',
#        'have already invited', 'have already invited for 10 hotels',
#        'have already invited for 10 hotels in second tranche',
#        'have already invited for 10 hotels in tranche', 'have invited',
#        'have invited for 10 hotels',
#        'have invited for 10 hotels in second tranche',
#        'have invited for 10 hotels in tranche', 'head',
#        'head of afghan government', 'head of aghanistan government',
#        'head of aghanistan interim government',
#        'head of elected afghan government', 'head of elected government',
#        'head of government', 'head of interim government',
#        'head of new afghan government',
#        'head of new elected afghan government',
#        'head of new elected government', 'head of new government',
#        'headway', 'her role', 'her role in erin brockovich',
#        'hewlett family', 'hewlett packard',
#        'hfcl kerry packer joint venture', 'hfcl kerry packer venture',
#        'high commissioner', 'high commissioner from pakistan', 'himself',
#        'his contract', 'his contract with worldtel', 'his role',
#        'his role in gladiator', 'his role in traffic', 'hit areas',
#        'hits indian markets', 'hits markets', 'hospitality arrangements',
#        'hotel jaipur ashok', 'hotels', 'hutchison', 'icc', 'icici bank',
#        'if happens', 'impasse', 'impasse over issues',
#        'impasse over issues of kashmir', 'implementation',
#        'implementation of plan', 'india', 'indian agent',
#        'indian companies', 'industry', 'initial bids',
#        'initial estimates', 'injured', 'instead will consolidated',
#        'instead will consolidated through friendly takeovers',
#        'instead will consolidated through takeovers',
#        'intensive brainstorming session',
#        'intensive day long brainstorming session',
#        'inter-company agreements', 'interest', 'interest rates',
#        'invitation', 'it', 'its subsidiaries', 'its two subsidiaries',
#        'j', 'j jayalalitha', 'jayalalitha', 'julia roberts', 'jury',
#        'karzai', 'kathmandu', 'kerala',
#        'kerala with 196 rooms along hotel airport ashok at kolkata with 149 rooms',
#        'killed', 'kovalam ashok beach resort', 'kumar birla', 'l',
#        'lacklustre revenue collections', 'lakme',
#        'larger borrowing programme',
#        'larger borrowing programme for 2002 03', 'largest private bank',
#        'las vegas fame', 'last batch', 'last batch of 715 items',
#        'last date', 'lazard capital', 'lcs', 'leading espouser', 'leash',
#        'led attacks', 'led attacks on afghanistan',
#        'legendary chief executive', 'level', 'level of industries',
#        'likely', 'linked customers', 'linked non-core customers', 'links',
#        'literature', 'long discussions', 'm', 'madhavpura case',
#        'madhavrao scindia', 'major', 'management', 'manufacturing',
#        'manufacturing sector', 'margins', 'market shares',
#        'marketing obligations not having in one part of country',
#        'match referee mike denness', 'match referee mike denness removed',
#        'match referee mike denness removed from rest',
#        'match referee mike denness removed from rest of series', 'matter',
#        'matter of policy', 'matter of policy relating',
#        'matter of policy relating to downstream petroleum sector',
#        'matter of policy relating to petroleum sector', 'may entered',
#        'may entered into for exchange',
#        'may entered into for exchange for period',
#        'may entered into for exchange of petroleum products',
#        'may entered into for exchange of petroleum products for period',
#        'mediation', 'meghalaya', 'meltdown', 'members', 'merge',
#        'merge with icici bank', 'merger', 'merger with uti bank',
#        'minimum', 'minister', "minister 's invitation",
#        'minister ab vajpayee', 'minister of tamil nadu', 'ministry',
#        'more trade', 'most glittery twosome', 'mother', 'move',
#        'much headway', 'much more trade', 'much need impetus',
#        'musharraf', 'national currency', 'need impetus', 'nepal',
#        "nepal 's prince dipendra", 'new york', 'nine broadcasting ï¿½',
#        'nobel prize', 'nobel prize for literature', 'non-core customers',
#        'noted film actor ashok kumar', 'obligation',
#        'obligation by entering', 'obligation by entering into agreement',
#        'obligation by entering into agreement with existing marketeers',
#        'obligation by entering into agreement with marketeers',
#        'obligation by entering into suitable agreement',
#        'obligation by entering into suitable agreement with existing marketeers',
#        'obligation by entering into suitable agreement with marketeers',
#        'obligation into agreement',
#        'obligation into agreement with existing marketeers',
#        'obligation into agreement with marketeers',
#        'obligation into suitable agreement',
#        'obligation into suitable agreement with existing marketeers',
#        'obligation into suitable agreement with marketeers', 'office',
#        'officer', 'officer of stanchart', 'oil sector regulator',
#        'one month', 'one test ban', 'one test ban for tampering',
#        'orange brand', 'osama bin', 'osama bin laden',
#        'osama bin laden in return',
#        'osama bin laden in return for easing',
#        'osama bin laden in return for easing of sanctions', 'other',
#        'other benchmark indices', 'other directors', 'others', 'outlets',
#        'over', 'p e ratio', 'pakistan',
#        "pakistan 's president pervez musharraf",
#        'pakistan president musharraf',
#        'pakistan president pervez musharraf',
#        'pakistan sponsored terrorism', 'parliament', 'payment crisis',
#        'pervez musharraf', 'petroleum sector', 'philip morris', 'place',
#        'police officials', 'policy', 'poor response',
#        'poor response from certain state governments',
#        'poor response from state governments', 'poor showing', 'power',
#        'powers', 'presence', 'presence of chinese goods',
#        'present hospitality arrangements', 'president',
#        'president fernando de la rua', 'president musharraf',
#        'president pervez musharraf', 'prime minister',
#        "prime minister 's invitation", 'prime minister ab vajpayee',
#        'prince dipendra', 'private', 'private sector',
#        'private sector investments', 'prize', 'prize for literature',
#        'profitability of petroleum majors', 'proportions',
#        'proposed oil sector regulator', 'public interest',
#        'punitive measures', 'qrs', 'quake hit areas', 'quarter',
#        'quarter of 2002', 'rana talwar', 'range', 'range of',
#        'real gdp growth', 'reducing', 'reinemund', 'response',
#        'response from certain state governments',
#        'response from state governments', 'rest', 'rest of series',
#        'restructuring', 'result', 'result in deficit',
#        'result in deficit increasing',
#        'result in deficit increasing from budget estimate',
#        'result in deficit increasing from budget estimate of rs. 116,314 crore',
#        'result in deficit increasing from budget estimate of rs. 116,314 crore to something',
#        'result in deficit increasing from budget estimate of rs. 116,314 crore to something like rs.',
#        'result in deficit increasing from budget estimate to something',
#        'result in deficit increasing from budget estimate to something like rs.',
#        'result in deficit increasing to something',
#        'result in deficit increasing to something like rs.',
#        'result in deficit to something',
#        'result in deficit to something like rs.', 'retail outlets',
#        'return', 'return in valuations', 'return to sanity',
#        'return to sanity in valuations', 'rise', 'rise in profitability',
#        'rise in profitability of petroleum majors',
#        'role in gtb price spurt prior to announcement of merger with uti bank',
#        'rumours', 'rural areas', 'russell crowe', 'sachin tendulkar',
#        'same', 'sanity', 'scores perfect 10', 'sebi', 'sebi bans sales',
#        'sebi bans short sales', 'sebi probes ketan parekh',
#        "sebi probes ketan parekh 's role", 'second quarter',
#        'second quarter of 2002', 'second tranche', 'sector',
#        'sector investments', 'serious fun', 'serious proportions',
#        'seven police officials', 'sezs', 'shifting', 'showing',
#        'significant m', 'sir', 'six indian players', 'six players',
#        'software companies', 'sorcerer', "sorcerer 's stone",
#        'spokesperson', 'sponsored terrorism', 'stand',
#        'stand against pakistan sponsored terrorism',
#        'stand against sponsored terrorism', 'stand against terrorism',
#        'state governments', 'steven', 'steven s reinemund', 'stock price',
#        'stone', 'substantial consolidation', 'substantial discounts',
#        'suitable agreement', 'supplies', 'supply', 'supply mechanism',
#        'supply mechanism by companies',
#        'supply mechanism by private companies',
#        'supply of controlled products', 'supply of products',
#        'supplying petrol', 'supporting actor award',
#        'supreme court ruling', 'suspended one test ban',
#        'suspended one test ban for tampering', 'sydney', 'talks',
#        'talks flounder', 'tapes air', 'tehelka',
#        "tehelka 's defence deal", 'telecommunications',
#        'television business ï¿½', 'tension', 'tension builds',
#        'tension builds between india', 'terms', 'terrorism',
#        'terrorists attack pentagon', 'their collections',
#        'their distribution', 'their equitable distribution',
#        'there will significant greenfield project', 'they',
#        'third tranche',
#        'third tranche of india tourism development corporation hotels',
#        'third tranche of tourism development corporation hotels', 'this',
#        'three fronts', 'thrid', 'tight leash', 'times awards night',
#        'tinseltown', 'to continue', 'to ensure', 'to merge',
#        'to merge with icici bank', 'to result', 'to result in deficit',
#        'to result in deficit increasing',
#        'to result in deficit increasing from budget estimate',
#        'to result in deficit increasing from budget estimate of rs. 116,314 crore',
#        'to result in deficit increasing from budget estimate of rs. 116,314 crore to something',
#        'to result in deficit increasing from budget estimate of rs. 116,314 crore to something like rs.',
#        'to result in deficit increasing from budget estimate to something',
#        'to result in deficit increasing from budget estimate to something like rs.',
#        'to result in deficit increasing to something',
#        'to result in deficit increasing to something like rs.',
#        'to result in deficit to something',
#        'to result in deficit to something like rs.', 'to return',
#        'to return in valuations', 'to return to sanity',
#        'to return to sanity in valuations', 'to welcome return',
#        'to welcome return in valuations', 'to welcome return to sanity',
#        'to welcome return to sanity in valuations', 'top slab', 'trade',
#        'trading', 'traffic', 'tranche',
#        'tranche of india tourism development corporation hotels',
#        'tranche of tourism development corporation hotels', 'transaction',
#        'transaction of narcotics', 'transition period',
#        'transition period for oil sector',
#        'transition period of two years',
#        'transition period of two years for oil sector', 'trust bank',
#        'tv', 'two biggest problems', 'two other directors', 'un',
#        'underworld', 'us', 'us 64', 'us led attacks',
#        'us led attacks on afghanistan', 'uti', 'uti bank', 'vajpayee',
#        'valuations', 'verification of such customers',
#        'vijayaraje scindia', 'washington', 'weakness',
#        'wealthiest man by sam walton of wal mart', 'welcome return',
#        'welcome return in valuations', 'welcome return to sanity',
#        'welcome return to sanity in valuations', 'while injured',
#        'will consolidated',
#        'will consolidated through friendly takeovers',
#        'will consolidated through takeovers', 'will hard pressed',
#        'will insufficient', 'will pressed', 'will region',
#        'will region of 5.0 %', 'will region of 5.0 % to 5.1 %',
#        'will region of 5.0 % to 5.1 % of gdp', 'will region to 5.1 %',
#        'will region to 5.1 % of gdp', 'will watchword', 'will year',
#        'will year of competition',
#        'will year of competition from within india',
#        'will year of even greater competition',
#        'will year of even greater competition from within india',
#        'will year of greater competition',
#        'will year of greater competition from within india',
#        'winter session', 'world', 'worldtel', 'worst cliche',
#        'worst cliche of 2001', 'wtc towers', 'yashwant sinha',
#        'yashwant sinha harping', 'year', 'york'], dtype=object)

# %% [markdown]
# ## Implementation of TransE algorithm:
#
# Here is the link of the research papers:
# https://proceedings.neurips.cc/paper/2013/file/1cecc7a77928ca8133fa24680a88d2f9-Paper.pdf

# %%
class TransE(nn.Module):
    def __init__(self, entity_len, rel_len, embedding_dim, margin=0.5):
        super(TransE, self).__init__()
        
        self.entity_embeddings = nn.Embedding(entity_len, embedding_dim,).cuda()
        self.rel_embeddings = nn.Embedding(rel_len, embedding_dim).cuda()        
        
        embeddings_init_bound = 6 / np.sqrt(embedding_dim)
        nn.init.uniform_(
            self.entity_embeddings.weight.data,
            a=-embeddings_init_bound,
            b=+embeddings_init_bound,
        )

        nn.init.uniform_(
            self.rel_embeddings.weight.data,
            a=-embeddings_init_bound,
            b=+embeddings_init_bound,
        )
        
        self.criterion = nn.MarginRankingLoss(
            margin=margin
        )
        
        norms = torch.norm(self.rel_embeddings.weight, p=2, dim=1).data
        self.rel_embeddings.weight.data = self.rel_embeddings.weight.data.div(
            norms.view(rel_len, 1).expand_as(self.rel_embeddings.weight))
        
    
    def entities_to_ids(self, entities):
        return entity2id[entities[0]]
    
    def generate_negative_triplets(self, pos_batch, all_entities):        
        current_batch_size = len(pos_batch)
        batch_subjs = pos_batch[:, 0:1]
        batch_relations = pos_batch[:, 2:3]
        batch_objs = pos_batch[:, 1:2]

        num_subj_corrupt = len(pos_batch) // 2
        num_obj_corrupt = len(pos_batch) - num_subj_corrupt
        pos_batch = torch.tensor(pos_batch, dtype=torch.long)

        corrupted_subj_indices = np.random.choice(np.arange(0, all_entities.shape[0]), size=num_subj_corrupt)
        corrupted_subjects = np.reshape(all_entities[corrupted_subj_indices], newshape=(-1, 1))
        corrupted_converted_subjects = np.apply_along_axis(self.entities_to_ids,1,corrupted_subjects).reshape(num_subj_corrupt,1)
        subject_based_corrupted_triples = np.concatenate(
            [corrupted_converted_subjects, (batch_objs[:num_subj_corrupt]).cpu(), (batch_relations[:num_subj_corrupt]).cpu()], axis=1)

        corrupted_obj_indices = np.random.choice(np.arange(0, all_entities.shape[0]), size=num_obj_corrupt)
        corrupted_objects = np.reshape(all_entities[corrupted_obj_indices], newshape=(-1, 1))
        corrupted_converted_objects = np.apply_along_axis(self.entities_to_ids,1,corrupted_objects).reshape(num_obj_corrupt,1)
        object_based_corrupted_triples = np.concatenate(
            [(batch_subjs[num_subj_corrupt:]).cpu(), corrupted_converted_objects, (batch_relations[num_subj_corrupt:]).cpu()], axis=1)
        batch_subjs.cuda()
        batch_relations.cuda()
        batch_objs.cuda()
        neg_batch = np.concatenate([subject_based_corrupted_triples, object_based_corrupted_triples], axis=0)
        neg_batch = torch.tensor(neg_batch, dtype=torch.long).cuda()
        return neg_batch

    
    
#     def entities_to_ids(self, entities):
#         return entity2id_dict[entities[0]]
    
    def forward(self, pos_batch, neg_batch):
        pos_score = self.score_triplets(pos_batch)
        neg_score = self.score_triplets(neg_batch)
        
        loss = self.compute_loss(pos_score, neg_score)
        return loss

    
    def train(self, triplets, all_entities, batchsize=32, epochs=1):
        triplets_len = triplets.shape[0]
        optimiser = optim.SGD(self.parameters(), lr=0.01, momentum=0.9)
        loss_hist = []
        for epoch in range(epochs):
            print("Epoch: {} is started.".format(epoch))
            for i in range(0,triplets_len,batchsize):
                #raises error if last batch contains only one element!!
                pos_batch = triplets[i:i+batchsize]
                neg_batch = self.generate_negative_triplets(pos_batch, all_entities)
                optimiser.zero_grad()

                loss = self.forward(pos_batch, neg_batch)
                loss_hist.append(loss)
                print("Calculated loss for iteration {}: {}".format(i,loss))
                loss.backward()
                optimiser.step()
            
        return loss_hist
        
    
    def compute_loss(self, pos_scores, neg_scores):
        y = np.repeat([1], repeats=pos_scores.shape[0])
        y = torch.tensor(y, dtype=torch.float)

        positive_scores = torch.tensor(pos_scores, dtype=torch.float)
        negative_scores = torch.tensor(neg_scores, dtype=torch.float)

        loss = self.criterion(pos_scores.cpu(), neg_scores.cpu(), y)
        
        return loss
    
    def split_triplets(self, triplets):
        h = triplets[:, 1:2]
        t = triplets[:, 3:4]
        r = triplets[:, 2:3]
        return h, t, r

    #it is very important how to vectorize code. Before, i was using numpy.apply_along_axis function to fetch the embeddings
    #since it is using numpy, apply function was fetching the embeddings one by one with using vectorization.
    #however, this was creating a ndarray of tensors which i do not want.
    #then, i realize it is possible to give a tensor(which has indices of relevant embeddings) to embeddings.weight.data
    #to fetch the relevant embeddings. Since I am fetching directly from nn.embedding (is of type tensor) now resulting
    #data is also tensor in the shape I want.
    
    def get_embedding_of_triplets(self, triplets):
        heads, tails, relations = self.split_triplets(triplets)
        #print("SHAPE ",self.entity_embeddings.weight[heads].reshape(heads.shape[0],-1).shape)
        return self.entity_embeddings.weight[heads].reshape(heads.shape[0],-1), self.entity_embeddings.weight[tails].reshape(heads.shape[0],-1), self.entity_embeddings.weight[relations].reshape(heads.shape[0],-1)   
        
    def score_triplets(self, triplets):
        print(self.entity_embeddings.weight.data)
        norms = torch.norm(self.entity_embeddings.weight, dim=1).data
        self.entity_embeddings.weight.data = self.entity_embeddings.weight.data.div(norms.view(entity_len, 1).expand_as(self.entity_embeddings.weight))
        print(self.entity_embeddings.weight.data)
        heads, tails, rels = self.get_embedding_of_triplets(triplets)
        sum_res = heads + rels - tails
        distances = torch.norm(sum_res, p=1, dim=1)
        distances_view = distances.view(size=(-1,))

        return distances_view

# %%
train_df = text_file.copy()
train_df = train_df.drop(['confidence_score'], axis = 1)

def map_triplets(df, entity2id, relation2id):
    print("mapping started")
    df['subject'] = df.apply(lambda L: entity2id[L[0]], axis=1)
    df['relation'] = df.apply(lambda L: relation2id[L[1]], axis=1)
    df['object'] = df.apply(lambda L: entity2id[L[2]], axis=1)
    print("mapping end")
map_triplets(train_df, entity2id, relation2id)

train_df.head()
# Out:
# mapping started
# mapping end
#    subject  relation  object
# 0      641       196     542
# 1      641       195     433
# 2      641       196     541
# 3      641       196     579
# 4      641       196     540

# %%
train_data = text_file.iloc[:, 1:]

embedding_dim = 300
model = TransE(entity_len, rel_len,  embedding_dim, margin=1)
pos_triplets = torch.from_numpy(train_df.values).cuda()

# %%
pos_triplets.shape
# Out:
# torch.Size([862, 3])

# %%
len_pos_triplets = pos_triplets.shape[0]
model.generate_negative_triplets(pos_triplets, all_entity)
#loss_hist = model.train(pos_triplets, all_entities,len_pos_triplets,epochs=100)


for name, param in model.named_parameters():
    if param.requires_grad:
        print (name, param.data)
    else:
        print(param.name)
# Out:
# entity_embeddings.weight tensor([[ 0.1745, -0.3000,  0.1776,  ...,  0.0933, -0.3138,  0.0355],
#         [-0.1722, -0.2806,  0.0762,  ..., -0.3423,  0.1884, -0.2712],
#         [ 0.0332,  0.0229, -0.3115,  ..., -0.0683,  0.2563,  0.1248],
#         ...,
#         [-0.1128, -0.2084, -0.2280,  ..., -0.2191, -0.0746, -0.1599],
#         [-0.2634, -0.0877,  0.0197,  ...,  0.1486,  0.2586, -0.3276],
#         [ 0.0413, -0.2985,  0.1191,  ...,  0.0284,  0.0844,  0.1672]],
#        device='cuda:0')
# rel_embeddings.weight tensor([[-0.0757, -0.0918, -0.0936,  ...,  0.0636, -0.0194, -0.0145],
#         [ 0.0603, -0.0318,  0.0122,  ..., -0.0257, -0.0944,  0.0513],
#         [-0.0103,  0.0244, -0.0359,  ..., -0.0349,  0.0602,  0.0424],
#         ...,
#         [ 0.0253,  0.0104,  0.0274,  ..., -0.0710,  0.0703, -0.0319],
#         [-0.0220, -0.0359, -0.0820,  ...,  0.0142,  0.0230, -0.0272],
#         [-0.0351, -0.0286,  0.0068,  ..., -0.0003, -0.0952,  0.0425]],
#        device='cuda:0')
# C:\Users\nrjkh\anaconda3\lib\site-packages\ipykernel_launcher.py:41: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
text_file.head()
# Out:
#    confidence_score            subject              relation  \
# 0               1.0  state governments  verify customers due
# 1               1.0  state governments                verify
# 2               1.0  state governments  verify customers due
# 3               1.0  state governments  verify customers due
# 4               1.0  state governments  verify customers due
#
#                                          object
# 0          poor response from state governments
# 1                     linked non-core customers
# 2  poor response from certain state governments
# 3               response from state governments
# 4                                 poor response

# %% [markdown]
# This is the final result.
# I have printed the embeddings of three entities below.

# %%
subj = entity2id['state governments']
rel = relation2id['verify customers due']
obj = entity2id['poor response from state governments']
print("subj index: ", subj)
print("rel index: ", rel)
print("obj index: ", obj)

subj_embed = model.entity_embeddings.weight[subj]
rel_embed = model.rel_embeddings.weight[rel]
obj_embed = model.entity_embeddings.weight[obj]

print("subj embed: ", subj_embed)
print("rel embed: ", rel_embed)
print("obj embed: ", obj_embed)
print("sum embed: ", subj_embed+rel_embed - obj_embed)
# Out:
# subj index:  641
# rel index:  196
# obj index:  542
# subj embed:  tensor([ 1.0169e-01,  1.5760e-01,  1.0111e-01, -1.6504e-01, -1.9245e-01,
#          1.7219e-01, -2.4491e-01,  1.4607e-01, -2.8628e-01, -2.1877e-01,
#         -1.5458e-01,  3.1030e-01,  4.1511e-02,  2.6320e-01, -2.7863e-01,
#         -3.3082e-01, -1.9666e-01, -2.3439e-01,  1.4035e-01,  3.0261e-01,
#          1.1460e-01,  2.0834e-01,  2.8014e-01,  2.3050e-01,  6.1045e-02,
#         -2.3531e-01, -1.8656e-01, -8.2295e-03, -3.2618e-01, -2.3911e-01,
#          2.8170e-01, -3.1591e-01, -1.4738e-01, -6.5919e-02, -1.4020e-01,
#          3.3690e-01,  3.3305e-01,  1.0934e-01, -2.8562e-01, -2.2550e-01,
#         -2.1800e-01,  2.2501e-01, -6.3844e-02, -3.3279e-02, -3.3343e-01,
#         -2.6974e-02, -3.0901e-01, -5.2196e-02, -5.2966e-02, -1.1670e-01,
